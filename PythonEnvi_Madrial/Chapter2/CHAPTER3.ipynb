# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/IS110_BPERFORMANCE_MADRIAL/PythonEnvi_Madrial
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/IS110_BPERFORMANCE_MADRIAL/PythonEnvi_Madrial'
# /content

# %%
# !pwd
#path for the working directory
# Out:
# /content

# %%
# !pip install virtualenv

# %%
# !virtualenv LJ
# Out:
# created virtual environment CPython3.12.12.final.0-64-x86_64 in 595ms
#   creator CPython3Posix(dest=/content/LJ, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, via=copy, app_data_dir=/root/.cache/virtualenv)
#     added seed packages: pip==26.0.1
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %%
# !source LJ/bin/activate

# %%
# !LJ/bin/pip install -r requirements.txt

# %%
# !LJ/bin/pip freeze > requirements.txt

# %%
# !LJ/bin/pip list
# Out:
# Package Version
# ------- -------
# pip     26.0.1

# %%
# !cat requirements.txt

# %%
x=0

if x > 50:
    print('Above 50')
elif x > 20:
    print('Above 20')
elif x > 10:
    print('Above 10')
elif x > 0:
    print('Above 0')
else:
    print('Something else')
# Out:
# Something else

# %%
hours = float(input("Enter Hours: "))
rate = float(input("Enter Rate: "))

if hours > 40:
    # Calculate regular pay for 40 hours plus 1.5x for extra hours
    overtime = hours - 40
    pay = (40 * rate) + (overtime * rate * 1.5)
else:
    # Standard calculation
    pay = hours * rate
# Out:
# Enter Hours: 10
# Enter Rate: 40

# %%
try:
    score = float(input("Enter score between 0 and 100: "))

    if score > 100 or score < 0:
            print("Error: Score is out of range.")
    elif score >= 98:
            print("Grade: 1.0")
    elif score >= 95:

            print("Grade: 1.25")
    elif score >= 90:

            print("Grade: 1.5")
    elif score >= 86:

            print("Grade: 1.75")
    elif score >= 82:

            print("Grade: 2.0")
    elif score >= 77:

            print("Grade: 2.25")
    elif score >= 75:

            print("Grade: 2.5")
    else:
            print("Grade: 2.0")

except ValueError:

    print("Error: Please enter a numeric value.")
# Out:
# Enter score between 0 and 100: 100
# Grade: 1.0

# %%
import pandas as pd
import numpy as np
