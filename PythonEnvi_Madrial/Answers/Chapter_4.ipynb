# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/IS110_BPERFORMANCE_MADRIAL/PythonEnvi_Madrial
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/ColabNotebooks/IS110_BPERFORMANCE_MADRIAL/PythonEnvi_Madrial'
# /content

# %%
# !pwd
#path for the working directory
# Out:
# /content

# %%
# !pip install virtualenv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 53.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 26.7 MB/s eta 0:00:00
# ...

# %%
# !virtualenv arah
# Out:
# created virtual environment CPython3.12.12.final.0-64-x86_64 in 418ms
#   creator CPython3Posix(dest=/content/arah, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, via=copy, app_data_dir=/root/.cache/virtualenv)
#     added seed packages: pip==26.0.1
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %%
# !source arah/bin/activate

# %%
# !arah/bin/pip install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# !arah/bin/pip freeze > requirements.txt

# %%
# !arah/bin/pip list
# Out:
# Package Version
# ------- -------
# pip     26.0.1

# %%
# !cat requirements.txt

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # CHAPTER 4

# %% [markdown]
# #EXERCISE 1

# %%
def compute_pay(hours, rate):

    if hours <= 40:
        pay = hours * rate
    else:
        regular_pay = 40 * rate
        overtime_hours = hours - 40
        overtime_rate = rate * 1.5
        overtime_pay = overtime_hours * overtime_rate
        pay = regular_pay + overtime_pay

    return pay

# %%
hours = 45
rate = 10
pay = compute_pay(hours, rate)
print(f"Pay for {hours} hours at ${rate}/hour: {pay}")
# Out:
# Pay for 45 hours at $10/hour: 475.0

# %% [markdown]
# # CHALLENGE

# %%
def computegrade(score):
    if 98 <= score <= 100:
        return "1.0"
    elif 94 <= score < 97:
        return "1.25"
    elif 90 <= score < 93:
        return "1.5"
    elif 86 <= score < 89:
        return "1.75"
    elif 82 <= score < 85:
        return "2.0"
    elif 78 <= score < 81:
        return "2.25"
    elif 75 <= score < 77:
        return "2.5"
    elif 0 <= score < 74:
        return "2.0"
    else:
        return "Invalid Score"

# Testing the function
test_score = float(input("Enter score: "))
print("Grade:", computegrade(test_score))
# Out:
# Enter score: 95
# Grade: 1.25
