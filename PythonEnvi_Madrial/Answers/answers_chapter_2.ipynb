# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/IS110_BPERFORMANCE_MADRIAL/PythonEnvi_Madrial
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/ColabNotebooks/IS110_BPERFORMANCE_MADRIAL/PythonEnvi_Madrial'
# /content

# %%
# !pwd
#path for the working directory
# Out:
# /content

# %%
# !pip install virtualenv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 56.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 33.1 MB/s eta 0:00:00
# ...

# %%
# !virtualenv larah
# Out:
# created virtual environment CPython3.12.12.final.0-64-x86_64 in 463ms
#   creator CPython3Posix(dest=/content/larah, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, via=copy, app_data_dir=/root/.cache/virtualenv)
#     added seed packages: pip==26.0.1
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %%
# !source larah/bin/activate

# %%
# !larah/bin/pip install -r requirements.txt

# %%
# !larah/bin/pip freeze > requirements.txt

# %%
# !larah/bin/pip list
# Out:
# Package Version
# ------- -------
# pip     26.0.1

# %%
# !cat requirements.txt

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # CHAPTER 2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# User Input

# %%
name = input('Who are you?')
print('Welcome',name)
# Out:
# Who are you?larah
# Welcome larah

# %%
inp = input('Europe floor?')
usf = int(inp) + 1
print('US floor', usf)
# Out:
# Europe floor?0
# US floor 1

# %% [markdown]
# # EXERCISE 1

# %%
name = input("Enter your name: ")
print("Hello", name)
# Out:
# Enter your name: larah
# Hello larah

# %% [markdown]
# #EXERCISE 2

# %%
hours = input('Enter Hours: ')
rate = input('Enter Rate: ')
pay = float(hours) * float(rate)
print('Pay:', pay)
# Out:
# Enter Hours: 72
# Enter Rate: 1.2
# Pay: 86.39999999999999

# %% [markdown]
# # EXERCISE 3

# %%
inp = input('Enter a number: ')
num = float(inp)
square = num ** 2
print('The square is:', square)
# Out:
# Enter a number: 11
# The square is: 121.0

# %% [markdown]
# #EXERCISE 4

# %%
inp = input('Enter a number: ')
num = float(inp)
square = num ** 2
print('The square is:', square)
# Out:
# Enter a number: 3
# The square is: 9.0

# %% [markdown]
# # CHALLENGE

# %%
celsius = input('Enter Celsius temperature: ')
fahr = (float(celsius) * 9/5) + 32
print('Fahrenheit temperature:', fahr)
# Out:
# Enter Celsius temperature: 22
# Fahrenheit temperature: 71.6
