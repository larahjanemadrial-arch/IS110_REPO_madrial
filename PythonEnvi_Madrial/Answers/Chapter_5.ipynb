# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/IS110_BPERFORMANCE_MADRIAL/PythonEnvi_Madrial
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/ColabNotebooks/IS110_BPERFORMANCE_MADRIAL/PythonEnvi_Madrial'
# /content

# %%
# !pwd
#path for the working directory
# Out:
# /content

# %%
# !pip install virtualenv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 69.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 24.4 MB/s eta 0:00:00
# ...

# %%
# !virtualenv LARAH
# Out:
# created virtual environment CPython3.12.12.final.0-64-x86_64 in 481ms
#   creator CPython3Posix(dest=/content/LARAH, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, via=copy, app_data_dir=/root/.cache/virtualenv)
#     added seed packages: pip==26.0.1
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %%
# !source LARAH/bin/activate

# %%
# !LARAH/bin/pip install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# !LARAH/bin/pip list
# Out:
# Package Version
# ------- -------
# pip     26.0.1

# %%
# !cat requirements.txt
# Out:
# cat: requirements.txt: No such file or directory

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # CHAPTER 5

# %%
from google.colab import drive
drive.mount ('/content/drive')

# %%
# %cd /content/drive/MyDrive/IS110_BPERFORMANCE_MADRIAL/PythonEnvi_Madrial

# %% [markdown]
# # EXERCISE 1

# %%
a = 2
b = 2.0
c = a

print(f"a: {a}, c: {c}")
print(f"a == c: {a == c}")
print(f"a is c: {a is c}")
# Out:
# a: 2, c: 2
# a == c: True
# a is c: True

# %% [markdown]
# # Challenge 1

# %%
total = 0
count = 0

while True:
    try:
        num_str = input('Enter a number: ')
        if num_str == 'done':
            break

        num = float(num_str)
        total += num
        count += 1
    except ValueError:
        print('Invalid input')

if count > 0:
    average = total / count
    print(f'{total} {count} {average}')
else:
    print('No numbers were entered.')
# Out:
# Enter a number: 5
# Enter a number: 4
# Enter a number: Bad data
# Invalid input
# Enter a number: 7
# Enter a number: done
# 16.0 3 5.333333333333333

# %% [markdown]
# # Challenge 2

# %%
numbers = [3, 1, 4, 1, 5, 9, 2, 6, 5]

max_value = max(numbers)
min_value = min(numbers)

print(f"Original list: {numbers}")
print(f"Maximum value: {max_value}")
print(f"Minimum value: {min_value}")
# Out:
# Original list: [3, 1, 4, 1, 5, 9, 2, 6, 5]
# Maximum value: 9
# Minimum value: 1

# %%
numbers = [3, 1, 4, 1, 5, 9, 2, 6, 5]

if not numbers:
    print("The list is empty.")
else:
    # Initialize max and min with the first element of the list
    current_max = numbers[0]
    current_min = numbers[0]

    # Iterate through the rest of the list
    for num in numbers[1:]:
        if num > current_max:
            current_max = num
        if num < current_min:
            current_min = num

    print(f"Original list: {numbers}")
    print(f"Maximum value (manual): {current_max}")
    print(f"Minimum value (manual): {current_min}")
# Out:
# Original list: [3, 1, 4, 1, 5, 9, 2, 6, 5]
# Maximum value (manual): 9
# Minimum value (manual): 1

# %% [markdown]
# # Task

# %%
filename = "/content/drive/MyDrive/IS110_BPERFORMANCE_MADRIAL/Copy of 01 Python Fundamentals, Part 1 (Workbook).ipynb"

try:
    with open(filename, 'r') as f:
        notebook_content = f.read()
        print(f"Successfully read the content of '{filename}'. First 500 characters:\n{notebook_content[:500]}")
except FileNotFoundError:
    print(f"Error: The file '{filename}' was not found. Please ensure it's in the correct directory or provide the full path.")
except Exception as e:
    print(f"An error occurred while reading the file: {e}")

# %%
import os
folder_path = "/content/drive/MyDrive/ISI10_BPERFORMANCE_MADRIAL/"

if os.path.exists(folder_path):
    print("Files in folder:")
    print(os.listdir(folder_path))
else:
    print("Folder not found. Did you mount your Google Drive?")

# %%
filename = "/content/drive/MyDrive/IS110_BPERFORMANCE_MADRIAL/Copy of 01 Python Fundamentals, Part 1 (Workbook).ipynb"

try:
    with open(filename, 'r') as f:
        notebook_content = f.read()
        print(f"Successfully read the content of '{filename}'. First 500 characters:\n{notebook_content[:500]}")
except FileNotFoundError:
    print(f"Error: The file '{filename}' was not found. Please ensure it's in the correct directory or provide the full path.")
except Exception as e:
    print(f"An error occurred while reading the file: {e}")

# %%
# !ls "/content/drive/MyDrive/IS110_BPERFORMANCE_MADRIAL/"

# %%
# !ls '/content/drive/MyDrive/IS110_BPERFORMANCE_MADRIAL/Colab Notebooks/'

# %%
import os, json

# Path to the notebook you successfully opened
filename = "/content/drive/MyDrive/IS110_BPERFORMANCE_MADRIAL/Copy of 01 Python Fundamentals, Part 1 (Workbook).ipynb"
output_file = "IS110_BPERFORMANCE_MADRIAL_extracted.py"

# Open and parse the notebook JSON
with open(filename, 'r', encoding='utf-8') as f:
    notebook_content = json.load(f)

# Extract only code cells
code_cells = []
for cell in notebook_content.get("cells", []):
    if cell.get("cell_type") == "code":
        code_cells.append("".join(cell.get("source", [])))

# Save them into a .py file
with open(output_file, "w", encoding="utf-8") as out:
    out.write("\n\n".join(code_cells))

print(f" Extraction complete! Code saved to '{output_file}'")

# %%
from google.colab import files
files.download("IS110_BPERFORMANCE_MADRIAL_extracted.py")
